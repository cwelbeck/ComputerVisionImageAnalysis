# %% [markdown]
# ### Setting up the Frameworks

# %%
# Install PyTorch
# !pip install https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl
# !pip install torchvision

# Import PyTorch libraries
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# Requirement already satisfied: torchvision in /home/nbuser/anaconda3_420/lib/python3.5/site-packages/torchvision-0.2.1-py3.5.egg (0.2.1)
# Requirement already satisfied: numpy in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (1.16.2)
# Requirement already satisfied: pillow>=4.1.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: torch in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (0.4.1)
# Requirement already satisfied: olefile in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pillow>=4.1.1->torchvision) (0.44)
# Libraries imported - ready to use PyTorch 0.4.1

# %% [markdown]
# ### Load Data

# %%
# Function to ingest data using training and test loaders
def load_dataset(data_path):
    # Load all of the images
    transformation = transforms.Compose([
        # transform to tensors
        transforms.ToTensor(),
        # Normalize the pixel values (in R, G, and B channels)
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Load all of the images, transforming them
    full_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=transformation
    )
    
    
    # Split into training (70% and testing (30%) datasets)
    train_size = int(0.7 * len(full_dataset))
    test_size = len(full_dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    
    # define a loader for the training data we can iterate through in 50-image batches
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
    
    # define a loader for the testing data we can iterate through in 50-image batches
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
        
    return train_loader, test_loader

import os

train_folder = "../data/classification/training"
img_size = (128,128)
images_per_batch = 18

# Get the class names
classes = os.listdir(train_folder)
classes.sort()
print(classes)

# Get the iterative dataloaders for test and training data
train_loader, test_loader = load_dataset(train_folder)
# Out:
# ['automobile', 'plane', 'train']

# %% [markdown]
# ### Define a Neural Network Model

# %%
# Create a neural net class
class Net(nn.Module):
    # Constructor
    def __init__(self, num_classes=3):
        super(Net, self).__init__()
        
        # Our images are RGB, so input channels = 3. We'll apply 24 filters in the first convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 24 outputs
        self.conv2 = nn.Conv2d(in_channels=24, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 48 outputs
        self.conv3 = nn.Conv2d(in_channels=24, out_channels=48, kernel_size=3, stride=1, padding=1)
        
        # We'll apply max pooling with a kernel size of 2
        self.pool = nn.MaxPool2d(kernel_size=2)
        
        # Our 128x128 image tensors will be pooled three times with a kernel size of 2. 128/2/2/2 is 16.
        # So our feature tensors are now 32 x 32, and we've generated 48 of them so our array is 16x16x48
        # We need to flatten these and feed them to a fully-connected layer
        # to map them to  the probability for each class
        self.fc = nn.Linear(in_features=16 * 16 * 48, out_features=num_classes)

    def forward(self, x):
        # Use a relu activation function after convolution 1 and pool
        x = F.relu(self.pool(self.conv1(x)))
      
        # Use a relu activation function after convolution 2 and pool
        x = F.relu(self.pool(self.conv2(x)))
        
        # Use a relu activation function after convolution 2)
        x = F.relu(self.conv2(x))
        
        # Use a relu activation function after convolution 2
        x = F.relu(self.conv2(x))
        
         # Use a relu activation function after convolution 3 and pool
        x = F.relu(self.pool(self.conv3(x)))
        
        # Flatten
        x = x.view(-1, 16 * 16 * 48)
        # Feed to fully-connected layer to predict class
        x = self.fc(x)
        # Return class probabilities via a log_softmax function 
        return F.log_softmax(x, dim=1)
    
device = "cpu"
if (torch.cuda.is_available()):
    # if GPU available, use cuda (on a cpu, training will take a considerable length of time!)
    device = "cuda"

# Create an instance of the model class and allocate it to the device
model = Net(num_classes=len(classes)).to(device)

print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=12288, out_features=3, bias=True)
# )

# %% [markdown]
# ### Train the Model

# %%
def train(model, device, train_loader, optimizer, epoch):
    # Set the model to training mode
    model.train()
    train_loss = 0
    print("Epoch:", epoch)
    # Process the images in batches
    for batch_idx, (data, target) in enumerate(train_loader):
        # Use the CPU or GPU as appropriate
        data, target = data.to(device), target.to(device)
        
        # Reset the optimizer
        optimizer.zero_grad()
        
        # Push the data forward through the model layers
        output = model(data)
        
        # Get the loss
        loss = loss_criteria(output, target)
        
        # Keep a running total
        train_loss += loss.item()
        
        # Backpropagate
        loss.backward()
        optimizer.step()
        
        # Print metrics so we see some progress
        print('\tTraining batch {} Loss: {:.6f}'.format(batch_idx + 1, loss.item()))
            
    # return average loss for the epoch
    return train_loss / len(train_loader.dataset)
            
            
def test(model, device, test_loader):
    # Switch the model to evaluation mode (so we don't backpropagate or drop)
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            
            # Get the predicted classes for this batch
            output = model(data)
            
            # Calculate the loss for this batch
            test_loss += loss_criteria(output, target).item()
            
            # Calculate the accuracy for this batch
            _, predicted = torch.max(output.data, 1)
            correct += torch.sum(target==predicted).item()

    # Calculate the average loss and total accuracy for this epoch
    test_loss /= len(test_loader.dataset)
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    # return average loss for the epoch
    return test_loss
    
    
# Use an "Adam" optimizer to adjust weights
# (see https://pytorch.org/docs/stable/optim.html#algorithms for details of supported algorithms)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Specify the loss criteria
loss_criteria = nn.CrossEntropyLoss()

# Track metrics in these arrays
epoch_nums = []
training_loss = []
validation_loss = []

# Train over 25 epochs
epochs = 25
print('Training on', device)
for epoch in range(1, epochs + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch)
        test_loss = test(model, device, test_loader)
        epoch_nums.append(epoch)
        training_loss.append(train_loss)
        validation_loss.append(test_loss)
# Out:
# Training on cpu
# Epoch: 1
# 	Training batch 1 Loss: 1.096916
# 	Training batch 2 Loss: 1.141754
# 	Training batch 3 Loss: 1.107590
# 	Training batch 4 Loss: 1.213587
# 	Training batch 5 Loss: 1.136882
# 	Training batch 6 Loss: 1.088238
# 	Training batch 7 Loss: 1.080534
# 	Training batch 8 Loss: 1.117079
# 	Training batch 9 Loss: 1.106053
# 	Training batch 10 Loss: 1.051050
# Validation set: Average loss: 0.0604, Accuracy: 34/72 (47%)
#
# Epoch: 2
# 	Training batch 1 Loss: 1.116402
# 	Training batch 2 Loss: 1.070207
# 	Training batch 3 Loss: 1.070562
# 	Training batch 4 Loss: 1.058143
# 	Training batch 5 Loss: 1.032741
# 	Training batch 6 Loss: 1.042439
# 	Training batch 7 Loss: 0.978159
# 	Training batch 8 Loss: 1.061437
# 	Training batch 9 Loss: 1.050984
# 	Training batch 10 Loss: 0.871733
# Validation set: Average loss: 0.0524, Accuracy: 40/72 (56%)
#
# Epoch: 3
# 	Training batch 1 Loss: 0.987177
# 	Training batch 2 Loss: 0.835205
# 	Training batch 3 Loss: 0.897482
# 	Training batch 4 Loss: 1.150019
# 	Training batch 5 Loss: 0.737379
# 	Training batch 6 Loss: 0.811364
# 	Training batch 7 Loss: 0.679278
# 	Training batch 8 Loss: 0.829945
# 	Training batch 9 Loss: 0.835709
# 	Training batch 10 Loss: 0.499520
# Validation set: Average loss: 0.0503, Accuracy: 37/72 (51%)
#
# Epoch: 4
# 	Training batch 1 Loss: 0.948886
# 	Training batch 2 Loss: 0.644666
# 	Training batch 3 Loss: 0.802793
# 	Training batch 4 Loss: 0.930328
# 	Training batch 5 Loss: 0.647055
# 	Training batch 6 Loss: 0.710097
# 	Training batch 7 Loss: 0.602107
# 	Training batch 8 Loss: 0.721200
# 	Training batch 9 Loss: 0.717300
# 	Training batch 10 Loss: 0.483233
# Validation set: Average loss: 0.0386, Accuracy: 50/72 (69%)
#
# Epoch: 5
# 	Training batch 1 Loss: 0.674645
# 	Training batch 2 Loss: 0.558471
# 	Training batch 3 Loss: 0.739107
# 	Training batch 4 Loss: 1.037091
# 	Training batch 5 Loss: 0.630027
# 	Training batch 6 Loss: 0.516844
# 	Training batch 7 Loss: 0.478541
# 	Training batch 8 Loss: 0.635585
# 	Training batch 9 Loss: 0.652384
# 	Training batch 10 Loss: 0.475785
# Validation set: Average loss: 0.0338, Accuracy: 55/72 (76%)
#
# Epoch: 6
# 	Training batch 1 Loss: 0.565504
# 	Training batch 2 Loss: 0.460590
# 	Training batch 3 Loss: 0.689666
# 	Training batch 4 Loss: 0.902668
# 	Training batch 5 Loss: 0.559852
# 	Training batch 6 Loss: 0.473921
# 	Training batch 7 Loss: 0.404905
# 	Training batch 8 Loss: 0.572927
# 	Training batch 9 Loss: 0.517111
# 	Training batch 10 Loss: 0.460205
# Validation set: Average loss: 0.0311, Accuracy: 56/72 (78%)
#
# Epoch: 7
# 	Training batch 1 Loss: 0.507531
# 	Training batch 2 Loss: 0.431271
# 	Training batch 3 Loss: 0.707874
# 	Training batch 4 Loss: 0.720484
# 	Training batch 5 Loss: 0.526757
# 	Training batch 6 Loss: 0.487543
# 	Training batch 7 Loss: 0.379328
# 	Training batch 8 Loss: 0.483984
# 	Training batch 9 Loss: 0.416932
# 	Training batch 10 Loss: 0.394034
# Validation set: Average loss: 0.0299, Accuracy: 54/72 (75%)
#
# Epoch: 8
# 	Training batch 1 Loss: 0.477440
# 	Training batch 2 Loss: 0.486416
# 	Training batch 3 Loss: 0.659457
# 	Training batch 4 Loss: 0.516933
# 	Training batch 5 Loss: 0.401941
# 	Training batch 6 Loss: 0.526171
# 	Training batch 7 Loss: 0.419120
# 	Training batch 8 Loss: 0.420225
# 	Training batch 9 Loss: 0.334585
# 	Training batch 10 Loss: 0.278757
# Validation set: Average loss: 0.0283, Accuracy: 55/72 (76%)
#
# Epoch: 9
# 	Training batch 1 Loss: 0.463387
# 	Training batch 2 Loss: 0.506109
# 	Training batch 3 Loss: 0.589177
# 	Training batch 4 Loss: 0.480091
# 	Training batch 5 Loss: 0.329775
# 	Training batch 6 Loss: 0.449616
# 	Training batch 7 Loss: 0.393831
# 	Training batch 8 Loss: 0.362946
# 	Training batch 9 Loss: 0.317486
# 	Training batch 10 Loss: 0.137716
# Validation set: Average loss: 0.0248, Accuracy: 59/72 (82%)
#
# Epoch: 10
# 	Training batch 1 Loss: 0.377291
# 	Training batch 2 Loss: 0.438949
# 	Training batch 3 Loss: 0.525348
# 	Training batch 4 Loss: 0.504766
# 	Training batch 5 Loss: 0.249607
# 	Training batch 6 Loss: 0.292840
# 	Training batch 7 Loss: 0.261955
# 	Training batch 8 Loss: 0.270303
# 	Training batch 9 Loss: 0.363437
# 	Training batch 10 Loss: 0.030075
# Validation set: Average loss: 0.0198, Accuracy: 60/72 (83%)
#
# Epoch: 11
# 	Training batch 1 Loss: 0.259270
# 	Training batch 2 Loss: 0.329553
# 	Training batch 3 Loss: 0.449274
# 	Training batch 4 Loss: 0.579953
# 	Training batch 5 Loss: 0.157371
# 	Training batch 6 Loss: 0.265259
# 	Training batch 7 Loss: 0.220716
# 	Training batch 8 Loss: 0.270650
# 	Training batch 9 Loss: 0.214776
# 	Training batch 10 Loss: 0.039887
# Validation set: Average loss: 0.0249, Accuracy: 58/72 (81%)
#
# Epoch: 12
# 	Training batch 1 Loss: 0.296314
# 	Training batch 2 Loss: 0.334486
# 	Training batch 3 Loss: 0.186185
# 	Training batch 4 Loss: 0.383654
# 	Training batch 5 Loss: 0.139587
# 	Training batch 6 Loss: 0.219807
# 	Training batch 7 Loss: 0.216246
# 	Training batch 8 Loss: 0.065758
# 	Training batch 9 Loss: 0.156351
# 	Training batch 10 Loss: 0.007896
# Validation set: Average loss: 0.0244, Accuracy: 63/72 (88%)
#
# Epoch: 13
# 	Training batch 1 Loss: 0.250215
# 	Training batch 2 Loss: 0.208891
# 	Training batch 3 Loss: 0.146961
# 	Training batch 4 Loss: 0.411906
# 	Training batch 5 Loss: 0.115197
# 	Training batch 6 Loss: 0.162470
# 	Training batch 7 Loss: 0.100521
# 	Training batch 8 Loss: 0.079352
# 	Training batch 9 Loss: 0.072934
# 	Training batch 10 Loss: 0.007132
# Validation set: Average loss: 0.0274, Accuracy: 61/72 (85%)
#
# Epoch: 14
# 	Training batch 1 Loss: 0.131550
# 	Training batch 2 Loss: 0.261880
# 	Training batch 3 Loss: 0.184881
# 	Training batch 4 Loss: 0.188502
# 	Training batch 5 Loss: 0.135685
# 	Training batch 6 Loss: 0.109340
# 	Training batch 7 Loss: 0.212883
# 	Training batch 8 Loss: 0.105781
# 	Training batch 9 Loss: 0.057202
# 	Training batch 10 Loss: 0.027587
# Validation set: Average loss: 0.0255, Accuracy: 59/72 (82%)
#
# Epoch: 15
# 	Training batch 1 Loss: 0.067449
# 	Training batch 2 Loss: 0.127007
# 	Training batch 3 Loss: 0.078311
# 	Training batch 4 Loss: 0.069860
# 	Training batch 5 Loss: 0.073660
# 	Training batch 6 Loss: 0.217974
# 	Training batch 7 Loss: 0.021686
# 	Training batch 8 Loss: 0.052868
# 	Training batch 9 Loss: 0.024761
# 	Training batch 10 Loss: 0.059402
# Validation set: Average loss: 0.0252, Accuracy: 61/72 (85%)
#
# Epoch: 16
# 	Training batch 1 Loss: 0.051633
# 	Training batch 2 Loss: 0.179455
# 	Training batch 3 Loss: 0.039104
# 	Training batch 4 Loss: 0.085948
# 	Training batch 5 Loss: 0.112551
# 	Training batch 6 Loss: 0.141453
# 	Training batch 7 Loss: 0.027297
# 	Training batch 8 Loss: 0.068389
# 	Training batch 9 Loss: 0.063021
# 	Training batch 10 Loss: 0.003514
# Validation set: Average loss: 0.0289, Accuracy: 58/72 (81%)
#
# Epoch: 17
# 	Training batch 1 Loss: 0.049811
# 	Training batch 2 Loss: 0.204238
# 	Training batch 3 Loss: 0.029279
# 	Training batch 4 Loss: 0.043325
# 	Training batch 5 Loss: 0.031895
# 	Training batch 6 Loss: 0.130109
# 	Training batch 7 Loss: 0.132357
# 	Training batch 8 Loss: 0.029130
# 	Training batch 9 Loss: 0.057877
# 	Training batch 10 Loss: 0.000468
# Validation set: Average loss: 0.0316, Accuracy: 64/72 (89%)
#
# Epoch: 18
# 	Training batch 1 Loss: 0.021206
# 	Training batch 2 Loss: 0.418476
# 	Training batch 3 Loss: 0.258037
# 	Training batch 4 Loss: 0.073292
# 	Training batch 5 Loss: 0.047277
# 	Training batch 6 Loss: 0.051805
# 	Training batch 7 Loss: 0.120739
# 	Training batch 8 Loss: 0.149330
# 	Training batch 9 Loss: 0.120276
# 	Training batch 10 Loss: 0.000790
# Validation set: Average loss: 0.0199, Accuracy: 60/72 (83%)
#
# Epoch: 19
# 	Training batch 1 Loss: 0.010213
# 	Training batch 2 Loss: 0.040241
# 	Training batch 3 Loss: 0.047222
# 	Training batch 4 Loss: 0.254384
# 	Training batch 5 Loss: 0.131002
# 	Training batch 6 Loss: 0.111675
# 	Training batch 7 Loss: 0.012122
# 	Training batch 8 Loss: 0.076644
# 	Training batch 9 Loss: 0.128543
# 	Training batch 10 Loss: 0.007705
# Validation set: Average loss: 0.0368, Accuracy: 56/72 (78%)
#
# Epoch: 20
# 	Training batch 1 Loss: 0.115509
# 	Training batch 2 Loss: 0.262796
# 	Training batch 3 Loss: 0.031968
# 	Training batch 4 Loss: 0.092012
# 	Training batch 5 Loss: 0.026573
# 	Training batch 6 Loss: 0.275312
# 	Training batch 7 Loss: 0.026728
# 	Training batch 8 Loss: 0.055438
# 	Training batch 9 Loss: 0.025280
# 	Training batch 10 Loss: 0.027819
# Validation set: Average loss: 0.0266, Accuracy: 59/72 (82%)
#
# Epoch: 21
# 	Training batch 1 Loss: 0.027480
# 	Training batch 2 Loss: 0.043344
# 	Training batch 3 Loss: 0.024283
# 	Training batch 4 Loss: 0.040696
# 	Training batch 5 Loss: 0.024898
# 	Training batch 6 Loss: 0.058548
# 	Training batch 7 Loss: 0.005187
# 	Training batch 8 Loss: 0.015468
# 	Training batch 9 Loss: 0.023195
# 	Training batch 10 Loss: 0.001785
# Validation set: Average loss: 0.0252, Accuracy: 61/72 (85%)
#
# Epoch: 22
# 	Training batch 1 Loss: 0.020826
# 	Training batch 2 Loss: 0.054515
# 	Training batch 3 Loss: 0.012962
# 	Training batch 4 Loss: 0.018163
# 	Training batch 5 Loss: 0.005974
# 	Training batch 6 Loss: 0.035868
# 	Training batch 7 Loss: 0.001575
# 	Training batch 8 Loss: 0.006395
# 	Training batch 9 Loss: 0.006499
# 	Training batch 10 Loss: 0.000357
# Validation set: Average loss: 0.0287, Accuracy: 62/72 (86%)
#
# Epoch: 23
# 	Training batch 1 Loss: 0.032346
# 	Training batch 2 Loss: 0.020523
# 	Training batch 3 Loss: 0.045906
# 	Training batch 4 Loss: 0.008908
# 	Training batch 5 Loss: 0.004214
# 	Training batch 6 Loss: 0.049244
# 	Training batch 7 Loss: 0.002166
# 	Training batch 8 Loss: 0.011512
# 	Training batch 9 Loss: 0.002052
# 	Training batch 10 Loss: 0.000729
# Validation set: Average loss: 0.0270, Accuracy: 61/72 (85%)
#
# Epoch: 24
# 	Training batch 1 Loss: 0.004358
# 	Training batch 2 Loss: 0.020476
# 	Training batch 3 Loss: 0.001343
# 	Training batch 4 Loss: 0.012321
# 	Training batch 5 Loss: 0.017545
# 	Training batch 6 Loss: 0.006435
# 	Training batch 7 Loss: 0.000680
# 	Training batch 8 Loss: 0.001600
# 	Training batch 9 Loss: 0.002110
# 	Training batch 10 Loss: 0.000115
# Validation set: Average loss: 0.0270, Accuracy: 64/72 (89%)
#
# Epoch: 25
# 	Training batch 1 Loss: 0.004919
# 	Training batch 2 Loss: 0.015938
# 	Training batch 3 Loss: 0.001582
# 	Training batch 4 Loss: 0.002975
# 	Training batch 5 Loss: 0.004307
# 	Training batch 6 Loss: 0.002469
# 	Training batch 7 Loss: 0.000376
# 	Training batch 8 Loss: 0.001071
# 	Training batch 9 Loss: 0.000904
# 	Training batch 10 Loss: 0.000078
# Validation set: Average loss: 0.0291, Accuracy: 61/72 (85%)

# %% [markdown]
# ### View the Loss History

# %%
from matplotlib import pyplot as plt
# %matplotlib inline


plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
#Pytorch doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import numpy as np

truelabels = []
predictions = []
model.eval()
print("Getting predictions from test set...")
for data, target in test_loader:
    for label in target.data.numpy():
        truelabels.append(label)
    for prediction in model(data).data.numpy().argmax(1):
        predictions.append(prediction) 

# Plot the confusion matrix
cm = confusion_matrix(truelabels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=85)
plt.yticks(tick_marks, classes)
plt.xlabel("Predicted Shape")
plt.ylabel("True Shape")
plt.show()
# Out:
# Getting predictions from test set...

# %% [markdown]
# ### Save the Model

# %%
# Save the model weights
model_file = 'vehicle-classifier.pth'
torch.save(model.state_dict(), model_file)
print("Model saved.")

# Delete the existing model variable
del model
# Out:
# Model saved.

# %% [markdown]
# ### Use the Model with New Data

# %%
# Helper function to resize image
def resize_image(img, size): 
    from PIL import Image

    # rescale the image so the longest edge is the right size
    img.thumbnail(size, Image.ANTIALIAS)
    
    # Create a new image of the right shape
    newimg = Image.new("RGB", size, (0, 0, 0))
    
    # Paste the rescaled image onto the new background
    newimg.paste(img, (int((size[0] - img.size[0]) / 2), int((size[1] - img.size[1]) / 2)))
  
    # return the resized image
    return newimg

# Function to predict the class of an image
def predict_image(classifier, image_array):
   
    # Set the classifer model to evaluation mode
    classifier.eval()
    
    # These are the classes our model can predict
    class_names = ['automobile', 'plane', 'train']
    
    # Apply the same transformations as we did for the training images
    transformation = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Preprocess the imagees
    image_tensor = torch.stack([transformation(image).float() for image in image_array])

    # Turn the input into a Variable
    input_features = image_tensor

    # Predict the class of each input image
    predictions = classifier(input_features)
    
    predicted_classes = []
    # Convert the predictions to a numpy array 
    for prediction in predictions.data.numpy():
        # The prediction for each image is the probability for each class, e.g. [0.8, 0.1, 0.2]
        # So get the index of the highest probability
        class_idx = np.argmax(prediction)
        # And append the corresponding class name to the results
        predicted_classes.append(class_names[class_idx])
    return np.array(predicted_classes)

print("Functions created - ready to use model for inference.")
# Out:
# Functions created - ready to use model for inference.

# %%
import os
from random import randint
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# load the saved model weights
model = Net(num_classes=3)
model.load_state_dict(torch.load(model_file))


#get the list of test image files
test_folder = '../data/classification/test'
test_image_files = os.listdir(test_folder)

# Empty array on which to store the images
image_arrays = []

size = (128,128)

fig = plt.figure(figsize=(12, 8))

# Get the images and show the predicted classes
for file_idx in range(len(test_image_files)):
    img = Image.open(os.path.join(test_folder, test_image_files[file_idx]))
    
    # resize the image so it matches the training set - it  must be the same size as the images on which the model was trained
    resized_img = np.array(resize_image(img, size))
                      
    # Add the image to the array of images
    image_arrays.append(resized_img)

# Get predictions from the array of image arrays
# Note that the model expects an array of 1 or more images - just like the batches on which it was trained
predictions = predict_image(model, np.array(image_arrays))

# plot easch image with its corresponding prediction
for idx in range(len(predictions)):
    a=fig.add_subplot(1,len(predictions),idx+1)
    imgplot = plt.imshow(image_arrays[idx])
    a.set_title(predictions[idx])
