# %% [markdown]
# ### Setting up the Frameworks

# %%
# Install PyTorch
# !pip install https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl
# !pip install torchvision

# Import PyTorch libraries
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# Requirement already satisfied: torchvision in /home/nbuser/anaconda3_420/lib/python3.5/site-packages/torchvision-0.2.1-py3.5.egg (0.2.1)
# Requirement already satisfied: numpy in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (1.16.2)
# Requirement already satisfied: pillow>=4.1.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: torch in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from torchvision) (0.4.1)
# Requirement already satisfied: olefile in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pillow>=4.1.1->torchvision) (0.44)
# ^COperation cancelled by user
#
# Libraries imported - ready to use PyTorch 0.4.1

# %% [markdown]
# ### Load Data

# %%
# Function to ingest data using training and test loaders
def load_dataset(data_path):
    # Load all of the images
    transformation = transforms.Compose([
        # transform to tensors
        transforms.ToTensor(),
        # Normalize the pixel values (in R, G, and B channels)
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Load all of the images, transforming them
    full_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=transformation
    )
    
    
    # Split into training (70% and testing (30%) datasets)
    train_size = int(0.7 * len(full_dataset))
    test_size = len(full_dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    
    # define a loader for the training data we can iterate through in 50-image batches
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
    
    # define a loader for the testing data we can iterate through in 50-image batches
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
        
    return train_loader, test_loader

import os

train_folder = "../data/classification/training"
img_size = (128,128)
images_per_batch = 18

# Get the class names
classes = os.listdir(train_folder)
classes.sort()
print(classes)

# Get the iterative dataloaders for test and training data
train_loader, test_loader = load_dataset(train_folder)
# Out:
# ['automobile', 'plane', 'train']

# %% [markdown]
# ### Define a Convolutional Neural Network Model

# %%
# Create a neural net class
class Net(nn.Module):
    # Constructor
    def __init__(self, num_classes=3):
        super(Net, self).__init__()
        
        # Our images are RGB, so input channels = 3. We'll apply 24 filters in the first convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 24 outputs
        self.conv2 = nn.Conv2d(in_channels=24, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 48 outputs
        self.conv3 = nn.Conv2d(in_channels=24, out_channels=48, kernel_size=3, stride=1, padding=1)
        
        # We'll apply max pooling with a kernel size of 2
        self.pool = nn.MaxPool2d(kernel_size=2)
        
        # Our 128x128 image tensors will be pooled three times with a kernel size of 2. 128/2/2/2 is 16.
        # So our feature tensors are now 32 x 32, and we've generated 48 of them so our array is 16x16x48
        # We need to flatten these and feed them to a fully-connected layer
        # to map them to  the probability for each class
        self.fc = nn.Linear(in_features=16 * 16 * 48, out_features=num_classes)

    def forward(self, x):
        # Use a relu activation function after convolution 1 and pool
        x = F.relu(self.pool(self.conv1(x)))
      
        # Use a relu activation function after convolution 2 and pool
        x = F.relu(self.pool(self.conv2(x)))
        
        # Use a relu activation function after convolution 2)
        x = F.relu(self.conv2(x))
        
        # Use a relu activation function after convolution 2
        x = F.relu(self.conv2(x))
        
         # Use a relu activation function after convolution 3 and pool
        x = F.relu(self.pool(self.conv3(x)))
        
        # Flatten
        x = x.view(-1, 16 * 16 * 48)
        # Feed to fully-connected layer to predict class
        x = self.fc(x)
        # Return class probabilities via a log_softmax function 
        return F.log_softmax(x, dim=1)
    
device = "cpu"
if (torch.cuda.is_available()):
    # if GPU available, use cuda (on a cpu, training will take a considerable length of time!)
    device = "cuda"

# Create an instance of the model class and allocate it to the device
model = Net(num_classes=len(classes)).to(device)

print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=12288, out_features=3, bias=True)
# )

# %% [markdown]
# ### Train the Model

# %%
def train(model, device, train_loader, optimizer, epoch):
    # Set the model to training mode
    model.train()
    train_loss = 0
    print("Epoch:", epoch)
    # Process the images in batches
    for batch_idx, (data, target) in enumerate(train_loader):
        # Use the CPU or GPU as appropriate
        data, target = data.to(device), target.to(device)
        
        # Reset the optimizer
        optimizer.zero_grad()
        
        # Push the data forward through the model layers
        output = model(data)
        
        # Get the loss
        loss = loss_criteria(output, target)

        # Keep a running total
        train_loss += loss.item()
        
        # Backpropagate
        loss.backward()
        optimizer.step()
        
        # Print metrics so we see some progress
        print('\tTraining batch {} Loss: {:.6f}'.format(batch_idx + 1, loss.item()))
            
    # return average loss for the epoch
    avg_loss = train_loss / (batch_idx+1)
    print('Training set: Average loss: {:.6f}'.format(avg_loss))
    return avg_loss
            
            
def test(model, device, test_loader):
    # Switch the model to evaluation mode (so we don't backpropagate or drop)
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        batch_count = 0
        for data, target in test_loader:
            batch_count += 1
            data, target = data.to(device), target.to(device)
            
            # Get the predicted classes for this batch
            output = model(data)
            
            # Calculate the loss for this batch
            test_loss += loss_criteria(output, target).item()
            
            # Calculate the accuracy for this batch
            _, predicted = torch.max(output.data, 1)
            correct += torch.sum(target==predicted).item()

    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss // batch_count
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(test_loader.dataset),
        100. * correct // len(test_loader.dataset)))
    
    # return average loss for the epoch
    return avg_loss
    
    
# Use an "Adam" optimizer to adjust weights
# (see https://pytorch.org/docs/stable/optim.html#algorithms for details of supported algorithms)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Specify the loss criteria
loss_criteria = nn.CrossEntropyLoss()

# Track metrics in these arrays
epoch_nums = []
training_loss = []
validation_loss = []

# Train over 25 epochs
epochs = 25
print('Training on', device)
for epoch in range(1, epochs + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch)
        test_loss = test(model, device, test_loader)
        epoch_nums.append(epoch)
        training_loss.append(train_loss)
        validation_loss.append(test_loss)
# Out:
# Training on cpu
# Epoch: 1
# 	Training batch 1 Loss: 1.092100
# 	Training batch 2 Loss: 1.036203
# 	Training batch 3 Loss: 1.179477
# 	Training batch 4 Loss: 1.205887
# 	Training batch 5 Loss: 1.116824
# 	Training batch 6 Loss: 1.192161
# 	Training batch 7 Loss: 1.107592
# 	Training batch 8 Loss: 1.099735
# 	Training batch 9 Loss: 1.110196
# 	Training batch 10 Loss: 1.101961
# Validation set: Average loss: 1.0963, Accuracy: 28/72 (39%)
#
# Epoch: 2
# 	Training batch 1 Loss: 1.137678
# 	Training batch 2 Loss: 1.157306
# 	Training batch 3 Loss: 1.105278
# 	Training batch 4 Loss: 1.090467
# 	Training batch 5 Loss: 1.105611
# 	Training batch 6 Loss: 1.035004
# 	Training batch 7 Loss: 1.078644
# 	Training batch 8 Loss: 1.068749
# 	Training batch 9 Loss: 1.046453
# 	Training batch 10 Loss: 1.002182
# Validation set: Average loss: 1.0256, Accuracy: 34/72 (47%)
#
# Epoch: 3
# 	Training batch 1 Loss: 1.024620
# 	Training batch 2 Loss: 1.025054
# 	Training batch 3 Loss: 0.979754
# 	Training batch 4 Loss: 0.897471
# 	Training batch 5 Loss: 0.942473
# 	Training batch 6 Loss: 0.872213
# 	Training batch 7 Loss: 0.906192
# 	Training batch 8 Loss: 1.045655
# 	Training batch 9 Loss: 0.690266
# 	Training batch 10 Loss: 0.691184
# Validation set: Average loss: 0.8440, Accuracy: 48/72 (67%)
#
# Epoch: 4
# 	Training batch 1 Loss: 0.751102
# 	Training batch 2 Loss: 0.681798
# 	Training batch 3 Loss: 0.795467
# 	Training batch 4 Loss: 0.579450
# 	Training batch 5 Loss: 0.983751
# 	Training batch 6 Loss: 0.711170
# 	Training batch 7 Loss: 0.814864
# 	Training batch 8 Loss: 0.987840
# 	Training batch 9 Loss: 0.635239
# 	Training batch 10 Loss: 0.559581
# Validation set: Average loss: 0.8677, Accuracy: 42/72 (58%)
#
# Epoch: 5
# 	Training batch 1 Loss: 0.736269
# 	Training batch 2 Loss: 0.576396
# 	Training batch 3 Loss: 0.769130
# 	Training batch 4 Loss: 0.594682
# 	Training batch 5 Loss: 0.785620
# 	Training batch 6 Loss: 0.597018
# 	Training batch 7 Loss: 0.731164
# 	Training batch 8 Loss: 0.945691
# 	Training batch 9 Loss: 0.573908
# 	Training batch 10 Loss: 0.447575
# Validation set: Average loss: 0.7662, Accuracy: 51/72 (71%)
#
# Epoch: 6
# 	Training batch 1 Loss: 0.732495
# 	Training batch 2 Loss: 0.468895
# 	Training batch 3 Loss: 0.731263
# 	Training batch 4 Loss: 0.603239
# 	Training batch 5 Loss: 0.741989
# 	Training batch 6 Loss: 0.536218
# 	Training batch 7 Loss: 0.669969
# 	Training batch 8 Loss: 1.051518
# 	Training batch 9 Loss: 0.578151
# 	Training batch 10 Loss: 0.292793
# Validation set: Average loss: 0.7039, Accuracy: 54/72 (75%)
#
# Epoch: 7
# 	Training batch 1 Loss: 0.851221
# 	Training batch 2 Loss: 0.422616
# 	Training batch 3 Loss: 0.611449
# 	Training batch 4 Loss: 0.532341
# 	Training batch 5 Loss: 0.686499
# 	Training batch 6 Loss: 0.648306
# 	Training batch 7 Loss: 0.613888
# 	Training batch 8 Loss: 0.838007
# 	Training batch 9 Loss: 0.487896
# 	Training batch 10 Loss: 0.270197
# Validation set: Average loss: 0.6908, Accuracy: 48/72 (67%)
#
# Epoch: 8
# 	Training batch 1 Loss: 0.907596
# 	Training batch 2 Loss: 0.424176
# 	Training batch 3 Loss: 0.539479
# 	Training batch 4 Loss: 0.411337
# 	Training batch 5 Loss: 0.614266
# 	Training batch 6 Loss: 0.633789
# 	Training batch 7 Loss: 0.639686
# 	Training batch 8 Loss: 0.752946
# 	Training batch 9 Loss: 0.395418
# 	Training batch 10 Loss: 0.178998
# Validation set: Average loss: 0.7046, Accuracy: 48/72 (67%)
#
# Epoch: 9
# 	Training batch 1 Loss: 0.881561
# 	Training batch 2 Loss: 0.455505
# 	Training batch 3 Loss: 0.505513
# 	Training batch 4 Loss: 0.275241
# 	Training batch 5 Loss: 0.523583
# 	Training batch 6 Loss: 0.596920
# 	Training batch 7 Loss: 0.602022
# 	Training batch 8 Loss: 0.668157
# 	Training batch 9 Loss: 0.358007
# 	Training batch 10 Loss: 0.140060
# Validation set: Average loss: 0.6567, Accuracy: 49/72 (68%)
#
# Epoch: 10
# 	Training batch 1 Loss: 0.729539
# 	Training batch 2 Loss: 0.357091
# 	Training batch 3 Loss: 0.414627
# 	Training batch 4 Loss: 0.249736
# 	Training batch 5 Loss: 0.484464
# 	Training batch 6 Loss: 0.515348
# 	Training batch 7 Loss: 0.531874
# 	Training batch 8 Loss: 0.628548
# 	Training batch 9 Loss: 0.336232
# 	Training batch 10 Loss: 0.091755
# Validation set: Average loss: 0.6774, Accuracy: 52/72 (72%)
#
# Epoch: 11
# 	Training batch 1 Loss: 0.589839
# 	Training batch 2 Loss: 0.266936
# 	Training batch 3 Loss: 0.350369
# 	Training batch 4 Loss: 0.201457
# 	Training batch 5 Loss: 0.449324
# 	Training batch 6 Loss: 0.444589
# 	Training batch 7 Loss: 0.496795
# 	Training batch 8 Loss: 0.609719
# 	Training batch 9 Loss: 0.269639
# 	Training batch 10 Loss: 0.058555
# Validation set: Average loss: 0.7484, Accuracy: 49/72 (68%)
#
# Epoch: 12
# 	Training batch 1 Loss: 0.547362
# 	Training batch 2 Loss: 0.260228
# 	Training batch 3 Loss: 0.340829
# 	Training batch 4 Loss: 0.134523
# 	Training batch 5 Loss: 0.351814
# 	Training batch 6 Loss: 0.432984
# 	Training batch 7 Loss: 0.553976
# 	Training batch 8 Loss: 0.515500
# 	Training batch 9 Loss: 0.166734
# 	Training batch 10 Loss: 0.046357
# Validation set: Average loss: 0.7020, Accuracy: 51/72 (71%)
#
# Epoch: 13
# 	Training batch 1 Loss: 0.418379
# 	Training batch 2 Loss: 0.245048
# 	Training batch 3 Loss: 0.368000
# 	Training batch 4 Loss: 0.078221
# 	Training batch 5 Loss: 0.279236
# 	Training batch 6 Loss: 0.267669
# 	Training batch 7 Loss: 0.466986
# 	Training batch 8 Loss: 0.470327
# 	Training batch 9 Loss: 0.191464
# 	Training batch 10 Loss: 0.071469
# Validation set: Average loss: 0.6327, Accuracy: 51/72 (71%)
#
# Epoch: 14
# 	Training batch 1 Loss: 0.260822
# 	Training batch 2 Loss: 0.122418
# 	Training batch 3 Loss: 0.301493
# 	Training batch 4 Loss: 0.074256
# 	Training batch 5 Loss: 0.374647
# 	Training batch 6 Loss: 0.243868
# 	Training batch 7 Loss: 0.272400
# 	Training batch 8 Loss: 0.377928
# 	Training batch 9 Loss: 0.152897
# 	Training batch 10 Loss: 0.065582
# Validation set: Average loss: 0.9041, Accuracy: 43/72 (60%)
#
# Epoch: 15
# 	Training batch 1 Loss: 0.304909
# 	Training batch 2 Loss: 0.150179
# 	Training batch 3 Loss: 0.236174
# 	Training batch 4 Loss: 0.040937
# 	Training batch 5 Loss: 0.518755
# 	Training batch 6 Loss: 0.382884
# 	Training batch 7 Loss: 0.379374
# 	Training batch 8 Loss: 0.325848
# 	Training batch 9 Loss: 0.092146
# 	Training batch 10 Loss: 0.026846
# Validation set: Average loss: 0.7786, Accuracy: 46/72 (64%)
#
# Epoch: 16
# 	Training batch 1 Loss: 0.239676
# 	Training batch 2 Loss: 0.198305
# 	Training batch 3 Loss: 0.628962
# 	Training batch 4 Loss: 0.172020
# 	Training batch 5 Loss: 0.156503
# 	Training batch 6 Loss: 0.114368
# 	Training batch 7 Loss: 0.296759
# 	Training batch 8 Loss: 0.320582
# 	Training batch 9 Loss: 0.076170
# 	Training batch 10 Loss: 0.012992
# Validation set: Average loss: 0.7126, Accuracy: 52/72 (72%)
#
# Epoch: 17
# 	Training batch 1 Loss: 0.607765
# 	Training batch 2 Loss: 0.198764
# 	Training batch 3 Loss: 0.141004
# 	Training batch 4 Loss: 0.131444
# 	Training batch 5 Loss: 0.117946
# 	Training batch 6 Loss: 0.126069
# 	Training batch 7 Loss: 0.251780
# 	Training batch 8 Loss: 0.285932
# 	Training batch 9 Loss: 0.255068
# 	Training batch 10 Loss: 0.024984
# Validation set: Average loss: 0.5823, Accuracy: 53/72 (74%)
#
# Epoch: 18
# 	Training batch 1 Loss: 0.197200
# 	Training batch 2 Loss: 0.081174
# 	Training batch 3 Loss: 0.217952
# 	Training batch 4 Loss: 0.150515
# 	Training batch 5 Loss: 0.177008
# 	Training batch 6 Loss: 0.138290
# 	Training batch 7 Loss: 0.164601
# 	Training batch 8 Loss: 0.168647
# 	Training batch 9 Loss: 0.111977
# 	Training batch 10 Loss: 0.059015
# Validation set: Average loss: 0.7496, Accuracy: 56/72 (78%)
#
# Epoch: 19
# 	Training batch 1 Loss: 0.498887
# 	Training batch 2 Loss: 0.089625
# 	Training batch 3 Loss: 0.085091
# 	Training batch 4 Loss: 0.094279
# 	Training batch 5 Loss: 0.096972
# 	Training batch 6 Loss: 0.041169
# 	Training batch 7 Loss: 0.306400
# 	Training batch 8 Loss: 0.148783
# 	Training batch 9 Loss: 0.085402
# 	Training batch 10 Loss: 0.004207
# Validation set: Average loss: 0.5686, Accuracy: 55/72 (76%)
#
# Epoch: 20
# 	Training batch 1 Loss: 0.201278
# 	Training batch 2 Loss: 0.141123
# 	Training batch 3 Loss: 0.043834
# 	Training batch 4 Loss: 0.030670
# 	Training batch 5 Loss: 0.107318
# 	Training batch 6 Loss: 0.032463
# 	Training batch 7 Loss: 0.099326
# 	Training batch 8 Loss: 0.085244
# 	Training batch 9 Loss: 0.035512
# 	Training batch 10 Loss: 0.002582
# Validation set: Average loss: 0.6250, Accuracy: 56/72 (78%)
#
# Epoch: 21
# 	Training batch 1 Loss: 0.065618
# 	Training batch 2 Loss: 0.026924
# 	Training batch 3 Loss: 0.025731
# 	Training batch 4 Loss: 0.020399
# 	Training batch 5 Loss: 0.042303
# 	Training batch 6 Loss: 0.018760
# 	Training batch 7 Loss: 0.027852
# 	Training batch 8 Loss: 0.038521
# 	Training batch 9 Loss: 0.006015
# 	Training batch 10 Loss: 0.000721
# Validation set: Average loss: 0.6446, Accuracy: 58/72 (81%)
#
# Epoch: 22
# 	Training batch 1 Loss: 0.045552
# 	Training batch 2 Loss: 0.005868
# 	Training batch 3 Loss: 0.047537
# 	Training batch 4 Loss: 0.040976
# 	Training batch 5 Loss: 0.013347
# 	Training batch 6 Loss: 0.004089
# 	Training batch 7 Loss: 0.020675
# 	Training batch 8 Loss: 0.014985
# 	Training batch 9 Loss: 0.002806
# 	Training batch 10 Loss: 0.000237
# Validation set: Average loss: 0.7164, Accuracy: 56/72 (78%)
#
# Epoch: 23
# 	Training batch 1 Loss: 0.093289
# 	Training batch 2 Loss: 0.008657
# 	Training batch 3 Loss: 0.004178
# 	Training batch 4 Loss: 0.006928
# 	Training batch 5 Loss: 0.015541
# 	Training batch 6 Loss: 0.002285
# 	Training batch 7 Loss: 0.034058
# 	Training batch 8 Loss: 0.020049
# 	Training batch 9 Loss: 0.005337
# 	Training batch 10 Loss: 0.000176
# Validation set: Average loss: 0.7470, Accuracy: 58/72 (81%)
#
# Epoch: 24
# 	Training batch 1 Loss: 0.008919
# 	Training batch 2 Loss: 0.006278
# 	Training batch 3 Loss: 0.002942
# 	Training batch 4 Loss: 0.001825
# 	Training batch 5 Loss: 0.012978
# 	Training batch 6 Loss: 0.014623
# 	Training batch 7 Loss: 0.010944
# 	Training batch 8 Loss: 0.013931
# 	Training batch 9 Loss: 0.001532
# 	Training batch 10 Loss: 0.000035
# Validation set: Average loss: 0.9042, Accuracy: 53/72 (74%)
#
# Epoch: 25
# 	Training batch 1 Loss: 0.006716
# 	Training batch 2 Loss: 0.012046
# 	Training batch 3 Loss: 0.028464
# 	Training batch 4 Loss: 0.003076
# 	Training batch 5 Loss: 0.006244
# 	Training batch 6 Loss: 0.002688
# 	Training batch 7 Loss: 0.003824
# 	Training batch 8 Loss: 0.004567
# 	Training batch 9 Loss: 0.001436
# 	Training batch 10 Loss: 0.000055
# Validation set: Average loss: 0.8641, Accuracy: 58/72 (81%)

# %% [markdown]
# ### View the Loss History

# %%
from matplotlib import pyplot as plt
# %matplotlib inline


plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# (Note that if the training loss continues to drop, but the validation loss doesn't - the model is *overfitting*!)
#
# ### Review Prediction Performance

# %%
#Pytorch doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import numpy as np

truelabels = []
predictions = []
model.eval()
print("Getting predictions from test set...")
for data, target in test_loader:
    for label in target.data.numpy():
        truelabels.append(label)
    for prediction in model(data).data.numpy().argmax(1):
        predictions.append(prediction) 

# Plot the confusion matrix
cm = confusion_matrix(truelabels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=85)
plt.yticks(tick_marks, classes)
plt.xlabel("Predicted Shape")
plt.ylabel("True Shape")
plt.show()
# Out:
# Getting predictions from test set...

# %% [markdown]
# ### Save the Model

# %%
# Save the model weights
model_file = 'vehicle-classifier.pth'
torch.save(model.state_dict(), model_file)
print("Model saved.")

# Delete the existing model variable
del model
# Out:
# Model saved.

# %% [markdown]
# ### Use the Model with New Data

# %%
# Helper function to resize image
def resize_image(src_img, size=(128,128), bg_color="white"): 
    from PIL import Image

    # rescale the image so the longest edge is the right size
    src_img.thumbnail(size, Image.ANTIALIAS)
    
    # Create a new image of the right shape
    new_image = Image.new("RGB", size, bg_color)
    
    # Paste the rescaled image onto the new background
    new_image.paste(src_img, (int((size[0] - src_img.size[0]) / 2), int((size[1] - src_img.size[1]) / 2)))
  
    # return the resized image
    return new_image

# Function to predict the class of an image
def predict_image(classifier, image_array):
   
    # Set the classifer model to evaluation mode
    classifier.eval()
    
    # These are the classes our model can predict
    class_names = ['automobile', 'plane', 'train']
    
    # Apply the same transformations as we did for the training images
    transformation = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Preprocess the imagees
    image_tensor = torch.stack([transformation(image).float() for image in image_array])

    # Turn the input into a Variable
    input_features = image_tensor

    # Predict the class of each input image
    predictions = classifier(input_features)
    
    predicted_classes = []
    # Convert the predictions to a numpy array 
    for prediction in predictions.data.numpy():
        # The prediction for each image is the probability for each class, e.g. [0.8, 0.1, 0.2]
        # So get the index of the highest probability
        class_idx = np.argmax(prediction)
        # And append the corresponding class name to the results
        predicted_classes.append(class_names[class_idx])
    return np.array(predicted_classes)

print("Functions created - ready to use model for inference.")
# Out:
# Functions created - ready to use model for inference.

# %%
import os
from random import randint
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# load the saved model weights
model = Net(num_classes=3)
model.load_state_dict(torch.load(model_file))


#get the list of test image files
test_folder = '../data/classification/test'
test_image_files = os.listdir(test_folder)

# Empty array on which to store the images
image_arrays = []

size = (128,128)
background_color = "white"

fig = plt.figure(figsize=(12, 8))

# Get the images and show the predicted classes
for file_idx in range(len(test_image_files)):
    img = Image.open(os.path.join(test_folder, test_image_files[file_idx]))
    
    # resize the image so it matches the training set - it  must be the same size as the images on which the model was trained
    resized_img = np.array(resize_image(img, size, background_color))
                      
    # Add the image to the array of images
    image_arrays.append(resized_img)

# Get predictions from the array of image arrays
# Note that the model expects an array of 1 or more images - just like the batches on which it was trained
predictions = predict_image(model, np.array(image_arrays))

# plot easch image with its corresponding prediction
for idx in range(len(predictions)):
    a=fig.add_subplot(1,len(predictions),idx+1)
    imgplot = plt.imshow(image_arrays[idx])
    a.set_title(predictions[idx])
